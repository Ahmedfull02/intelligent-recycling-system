# %% [markdown]
# # Yolo Notebook

# %% [markdown]
# Importing libraries

# %%
import cv2
import torch

# %% [markdown]
# Model Backbone

# %%
import torch.nn as nn

class YOLO(nn.Module):
    def __init__(self, num_classes = 6, num_anchors = 3, grid_size = 7):
        super(YOLO, self).__init__()
        self.num_classes = num_classes
        self.num_anchors = num_anchors
        self.grid_size = grid_size
        
        self.backbone = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
        
        self.detector = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(256 * (grid_size // 4)**2, grid_size * grid_size * (num_anchors * 5 + num_classes))
        )
        
    def forward(self, x):
        features = self.backbone(x)
        predictions = self.detector(features)
        return predictions.view(-1, self.grid_size, self.grid_size, self.num_anchors * 5 + self.num_classes)

# %%
model = YOLO(num_classes=6)
model
# Out:
# YOLO(
#   (backbone): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (detector): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Linear(in_features=256, out_features=1029, bias=True)
#   )
# )

# %% [markdown]
# Modular Building Blocks
# Create a block

# %%
class ConvBlock(nn.Module):
    #This block contains Conv2d, BatchNorm, ReLU.
    def __init__(self, in_channels, out_channels, kernel_size, stride, padding):
        super(ConvBlock, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding)
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU
        
    def forward(self, x):
        return self.relu(self.bn(self.conv(x)))

# %%
class YOLOBackbone(nn.Module):
    def __init__(self):
        super(YOLOBackbone, self).__init__()
        self.layers = nn.Sequential(
            ConvBlock(3,32,3,1,1),
            nn.MaxPool2d(2,2),
            ConvBlock(32,64,3,1,1),
            nn.MaxPool2d(2,2),
            ConvBlock(64,128,3,1,1),
            nn.MaxPool2d(2,2)
        )
    def forward(self, x):
        return self.layers(x)

# %% [markdown]
# Detection Head

# %%
class YOLOHead(nn.Module):
    def __init__(self, grid_size, num_classes, num_anchors):
        super(YOLOHead, self).__init__()
        self.grid_size = grid_size
        self.num_classes = num_classes
        self.num_anchors = num_anchors
        self.detector = nn.Conv2d(128, num_anchors * (5 + num_classes), kernel_size=1)

    def forward(self, x):
        return self.detector(x).permute(0,2,3,1).contiguous()

# %% [markdown]
# assemble YOLO Model

# %%
class YOLO(nn.Module):
    def __init__(self, grid_size=7, num_classes=20, num_anchors=3):
        super(YOLO, self).__init__()
        self.backbone = YOLOBackbone()
        self.head = YOLOHead(grid_size, num_classes, num_anchors)

    def forward(self, x):
        features = self.backbone(x)
        predictions = self.head(features)
        return predictions

# Example usage
model = YOLO(grid_size=7, num_classes=20, num_anchors=3)
print(model)
# Out:
# YOLO(
#   (backbone): YOLOBackbone(
#     (layers): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): ConvBlock(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): ConvBlock(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (head): YOLOHead(
#     (detector): Conv2d(128, 75, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %% [markdown]
# Anchor Boxes

# %%
import numpy as np

def generate_anchors(scales, ratios):
    anchors = []
    for s in scales:
        for r in ratios:
            w = s * np.sqrt(r)
            h = s / np.sqrt(r)
            anchors.append((w,h))
    return anchors

# %% [markdown]
# YOLO expects bounding box coordinates relative to the image size (values between 0 and 1). Here’s how you can convert VOC annotations to YOLO format:

# %%
def convert_to_yolo_format(w, h, bbx):
    x_min, y_min, x_max, y_max = bbx
    x_center = (x_min + x_max) / 2 / w
    y_center = (y_min + y_max) / 2 / h
    b_w = (x_min - x_max) / w
    b_h = (x_min - x_max) / h
    return [x_center, y_center, b_w, b_h]

# %% [markdown]
# Data augmentation

# %%
import torchvision.transforms as transforms

train_transforms = transforms.Compose([
    transforms.Resize((448, 448)),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor()
])

# %% [markdown]
# Loss Function

# %%
def yolo_loss(predictions, targets, num_classes, lambda_coord=5, lambda_noobj=0.5):
    """
    Computes YOLO loss.
    - predictions: Predicted tensor.
    - targets: Ground truth tensor.
    """
    # Unpack predictions and targets
    pred_boxes = predictions[..., :4]
    pred_conf = predictions[..., 4]
    pred_classes = predictions[..., 5:]
    target_boxes = targets[..., :4]
    target_conf = targets[..., 4]
    target_classes = targets[..., 5:]
    
    # Localization Loss
    box_loss = lambda_coord * torch.sum((pred_boxes - target_boxes) ** 2)

    # Confidence Loss
    obj_loss = torch.sum((pred_conf - target_conf) ** 2)
    noobj_loss = lambda_noobj * torch.sum((pred_conf[target_conf == 0]) ** 2)

    # Classification Loss
    class_loss = torch.sum((pred_classes - target_classes) ** 2)

    # Total Loss
    total_loss = box_loss + obj_loss + noobj_loss + class_loss
    return total_loss

# %% [markdown]
# dataset class

# %%
pip install requests
# Out:
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl (102 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2025.1.31 charset-normalizer-3.4.1 idna-3.10 requests-2.32.3 urllib3-2.3.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# https://colab.research.google.com/drive/1QuLLsvX-DnOcOVWxcKWglIzDnxV_OHxE?usp=sharing#scrollTo=9ILzwujhyDmX

# %%
# !wget http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# !unzip /content/annotations_trainval2014.zip
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from coco_dataset import coco_dataset_download as cocod

class_names = ['newspaper', 'cardboard box', 'tissue box', 'bottle', 'wine glass', 'cup']  # List of class names you want to download
images_count = 500  # Count of images
annotations_path = r'C:\Users\YOGA\Desktop\Master s3\NoSQL\repo\intelligent-recycling-system\content\annotations\instances_train2014.json'

# Loop through each class and call the download function
for class_name in class_names:
    print(f"Downloading images for class: {class_name}")
    cocod.coco_dataset_download(class_name, images_count, annotations_path)
# Out:
# Downloading images for class: newspaper
# loading annotations into memory...
# Done (t=29.06s)
# creating index...
# index created!
# no.of image: 1
# no.of image: 2
# no.of image: 3
# no.of image: 4
# no.of image: 5
# no.of image: 6
# no.of image: 7
# no.of image: 8
# no.of image: 9
# no.of image: 10
# no.of image: 11
# no.of image: 12
# no.of image: 13
# no.of image: 14
# no.of image: 15
# no.of image: 16
# no.of image: 17
# no.of image: 18
# no.of image: 19
# no.of image: 20
# no.of image: 21
# no.of image: 22
# no.of image: 23
# no.of image: 24
# no.of image: 25
# no.of image: 26
# no.of image: 27
# no.of image: 28
# no.of image: 29
# no.of image: 30
# no.of image: 31
# no.of image: 32
# no.of image: 33
# no.of image: 34
# no.of image: 35
# no.of image: 36
# no.of image: 37
# no.of image: 38
# no.of image: 39
# no.of image: 40
# no.of image: 41
# no.of image: 42
# no.of image: 43
# no.of image: 44
# no.of image: 45
# no.of image: 46
# no.of image: 47
# no.of image: 48
# no.of image: 49
# no.of image: 50
# no.of image: 51
# no.of image: 52
# no.of image: 53
# no.of image: 54
# no.of image: 55
# no.of image: 56
# no.of image: 57
# no.of image: 58
# no.of image: 59
# no.of image: 60
# no.of image: 61
# no.of image: 62
# no.of image: 63
# no.of image: 64
# no.of image: 65
# no.of image: 66
# no.of image: 67
# no.of image: 68
# no.of image: 69
# no.of image: 70
# no.of image: 71
# no.of image: 72
# no.of image: 73
# no.of image: 421
# no.of image: 422
# no.of image: 423
# no.of image: 424
# no.of image: 425
# no.of image: 426
# no.of image: 427
# no.of image: 428
# no.of image: 429
# no.of image: 430
# no.of image: 431
# no.of image: 432
# no.of image: 433
# no.of image: 434
# no.of image: 435
# no.of image: 436
# no.of image: 437
# no.of image: 438
# no.of image: 439
# no.of image: 440
# no.of image: 441
# no.of image: 442
# no.of image: 443
# no.of image: 444
# no.of image: 445
# no.of image: 446
# no.of image: 447
# no.of image: 448
# no.of image: 449
# no.of image: 450
# no.of image: 451
# no.of image: 452
# no.of image: 453
# no.of image: 454
# no.of image: 455
# no.of image: 456
# no.of image: 457
# no.of image: 458
# no.of image: 459
# no.of image: 460
# no.of image: 461
# no.of image: 462
# no.of image: 463
# no.of image: 464
# no.of image: 465
# no.of image: 466
# no.of image: 467
# no.of image: 468
# no.of image: 469
# no.of image: 470
# no.of image: 471
# no.of image: 472
# no.of image: 473
# no.of image: 474
# no.of image: 475
# no.of image: 476
# no.of image: 477
# no.of image: 478
# no.of image: 479
# no.of image: 480
# no.of image: 481
# no.of image: 482
# no.of image: 483
# no.of image: 484
# no.of image: 485
# no.of image: 486
# no.of image: 487
# no.of image: 488
# no.of image: 489
# no.of image: 490
# no.of image: 491
# no.of image: 492
# no.of image: 493
# no.of image: 494
# no.of image: 495
# no.of image: 496
# no.of image: 497
# no.of image: 498
# no.of image: 499
# no.of image: 500
# finished images download
# Downloading images for class: cardboard box
# loading annotations into memory...
# Done (t=15.60s)
# creating index...
# index created!
# no.of image: 1
# no.of image: 2
# no.of image: 3
# no.of image: 4
# no.of image: 5
# no.of image: 6
# no.of image: 7
# no.of image: 8
# no.of image: 9
# no.of image: 10
# no.of image: 11
# no.of image: 12
# no.of image: 13
# no.of image: 14
# no.of image: 15
# no.of image: 16
# no.of image: 17
# no.of image: 18
# no.of image: 19
# no.of image: 20
# no.of image: 21
# no.of image: 22
# no.of image: 23
# no.of image: 24
# no.of image: 25
# no.of image: 26
# no.of image: 27
# no.of image: 28
# no.of image: 29
# no.of image: 30
# no.of image: 31
# no.of image: 32
# no.of image: 33
# no.of image: 34
# no.of image: 35
# no.of image: 36
# no.of image: 37
# no.of image: 38
# no.of image: 39
# no.of image: 40
# no.of image: 41
# no.of image: 42
# no.of image: 43
# no.of image: 44
# no.of image: 45
# no.of image: 46
# no.of image: 47
# no.of image: 48
# no.of image: 49
# no.of image: 50
# no.of image: 51
# no.of image: 52
# no.of image: 53
# no.of image: 54
# no.of image: 55
# no.of image: 56
# no.of image: 57
# no.of image: 58
# no.of image: 59
# no.of image: 60
# no.of image: 61
# no.of image: 62
# no.of image: 63
# no.of image: 64
# no.of image: 65
# no.of image: 66
# no.of image: 67
# no.of image: 68
# no.of image: 69
# no.of image: 70
# no.of image: 71
# no.of image: 72
# no.of image: 73
# no.of image: 74
# no.of image: 75
# no.of image: 76
# no.of image: 77
# no.of image: 78
# no.of image: 79
# no.of image: 80
# no.of image: 81
# no.of image: 82
# no.of image: 83
# no.of image: 84
# no.of image: 85
# no.of image: 86
# no.of image: 87
# no.of image: 436
# no.of image: 437
# no.of image: 438
# no.of image: 439
# no.of image: 440
# no.of image: 441
# no.of image: 442
# no.of image: 443
# no.of image: 444
# no.of image: 445
# no.of image: 446
# no.of image: 447
# no.of image: 448
# no.of image: 449
# no.of image: 450
# no.of image: 451
# no.of image: 452
# no.of image: 453
# no.of image: 454
# no.of image: 455
# no.of image: 456
# no.of image: 457
# no.of image: 458
# no.of image: 459
# no.of image: 460
# no.of image: 461
# no.of image: 462
# no.of image: 463
# no.of image: 464
# no.of image: 465
# no.of image: 466
# no.of image: 467
# no.of image: 468
# no.of image: 469
# no.of image: 470
# no.of image: 471
# no.of image: 472
# no.of image: 473
# no.of image: 474
# no.of image: 475
# no.of image: 476
# no.of image: 477
# no.of image: 478
# no.of image: 479
# no.of image: 480
# no.of image: 481
# no.of image: 482
# no.of image: 483
# no.of image: 484
# no.of image: 485
# no.of image: 486
# no.of image: 487
# no.of image: 488
# no.of image: 489
# no.of image: 490
# no.of image: 491
# no.of image: 492
# no.of image: 493
# no.of image: 494
# no.of image: 495
# no.of image: 496
# no.of image: 497
# no.of image: 498
# no.of image: 499
# no.of image: 500
# finished images download
# Downloading images for class: tissue box
# loading annotations into memory...
# Done (t=17.22s)
# creating index...
# index created!
# no.of image: 1
# no.of image: 2
# no.of image: 3
# no.of image: 4
# no.of image: 5
# no.of image: 6
# no.of image: 7
# no.of image: 8
# no.of image: 9
# no.of image: 10
# no.of image: 11
# no.of image: 12
# no.of image: 13
# no.of image: 14
# no.of image: 15
# no.of image: 16
# no.of image: 17
# no.of image: 18
# no.of image: 19
# no.of image: 20
# no.of image: 21
# no.of image: 22
# no.of image: 23
# no.of image: 24
# no.of image: 25
# no.of image: 26
# no.of image: 27
# no.of image: 28
# no.of image: 29
# no.of image: 30
# no.of image: 31
# no.of image: 32
# no.of image: 33
# no.of image: 34
# no.of image: 35
# no.of image: 36
# no.of image: 37
# no.of image: 38
# no.of image: 39
# no.of image: 40
# no.of image: 41
# no.of image: 42
# no.of image: 43
# no.of image: 44
# no.of image: 45
# no.of image: 46
# no.of image: 47
# no.of image: 48
# no.of image: 49
# no.of image: 50
# no.of image: 51
# no.of image: 52
# no.of image: 53
# no.of image: 54
# no.of image: 55
# no.of image: 56
# no.of image: 57
# no.of image: 58
# no.of image: 59
# no.of image: 60
# no.of image: 61
# no.of image: 62
# no.of image: 63
# no.of image: 64
# no.of image: 65
# no.of image: 66
# no.of image: 67
# no.of image: 68
# no.of image: 69
# no.of image: 70
# no.of image: 71
# no.of image: 72
# no.of image: 73
# no.of image: 74
# no.of image: 75
# no.of image: 76
# no.of image: 77
# no.of image: 78
# no.of image: 79
# no.of image: 80
# no.of image: 81
# no.of image: 82
# no.of image: 83
# no.of image: 84
# no.of image: 85
# no.of image: 86
# no.of image: 87
# no.of image: 88
# no.of image: 89
# no.of image: 90
# no.of image: 91
# no.of image: 92
# no.of image: 93
# no.of image: 94
# no.of image: 95
# no.of image: 96
# no.of image: 97
# no.of image: 98
# no.of image: 99
# no.of image: 100
# no.of image: 101
# no.of image: 102
# no.of image: 450
# no.of image: 451
# no.of image: 452
# no.of image: 453
# no.of image: 454
# no.of image: 455
# no.of image: 456
# no.of image: 457
# no.of image: 458
# no.of image: 459
# no.of image: 460
# no.of image: 461
# no.of image: 462
# no.of image: 463
# no.of image: 464
# no.of image: 465
# no.of image: 466
# no.of image: 467
# no.of image: 468
# no.of image: 469
# no.of image: 470
# no.of image: 471
# no.of image: 472
# no.of image: 473
# no.of image: 474
# no.of image: 475
# no.of image: 476
# no.of image: 477
# no.of image: 478
# no.of image: 479
# no.of image: 480
# no.of image: 481
# no.of image: 482
# no.of image: 483
# no.of image: 484
# no.of image: 485
# no.of image: 486
# no.of image: 487
# no.of image: 488
# no.of image: 489
# no.of image: 490
# no.of image: 491
# no.of image: 492
# no.of image: 493
# no.of image: 494
# no.of image: 495
# no.of image: 496
# no.of image: 497
# no.of image: 498
# no.of image: 499
# no.of image: 500
# finished images download
# Downloading images for class: bottle
# loading annotations into memory...
# Done (t=17.16s)
# creating index...
# index created!
# no.of image: 1
# no.of image: 2
# no.of image: 3
# no.of image: 4
# no.of image: 5
# no.of image: 6
# no.of image: 7
# no.of image: 8
# no.of image: 9
# no.of image: 10
# no.of image: 11
# no.of image: 12
# no.of image: 13
# no.of image: 14
# no.of image: 15
# no.of image: 16
# no.of image: 17
# no.of image: 18
# no.of image: 19
# no.of image: 20
# no.of image: 21
# no.of image: 22
# no.of image: 23
# no.of image: 24
# no.of image: 25
# no.of image: 26
# no.of image: 27
# no.of image: 28
# no.of image: 29
# no.of image: 30
# no.of image: 31
# no.of image: 32
# no.of image: 33
# no.of image: 34
# no.of image: 35
# no.of image: 36
# no.of image: 37
# no.of image: 38
# no.of image: 39
# no.of image: 40
# no.of image: 41
# no.of image: 42
# no.of image: 43
# no.of image: 44
# no.of image: 45
# no.of image: 46
# no.of image: 47
# no.of image: 48
# no.of image: 49
# no.of image: 50
# no.of image: 51
# no.of image: 52
# no.of image: 53
# no.of image: 54
# no.of image: 55
# no.of image: 56
# no.of image: 57
# no.of image: 58
# no.of image: 59
# no.of image: 60
# no.of image: 61
# no.of image: 62
# no.of image: 63
# no.of image: 64
# no.of image: 65
# no.of image: 66
# no.of image: 67
# no.of image: 68
# no.of image: 69
# no.of image: 70
# no.of image: 71
# no.of image: 72
# no.of image: 73
# no.of image: 74
# no.of image: 75
# no.of image: 76
# no.of image: 77
# no.of image: 78
# no.of image: 79
# no.of image: 80
# no.of image: 81
# no.of image: 82
# no.of image: 83
# no.of image: 84
# no.of image: 85
# no.of image: 86
# no.of image: 87
# no.of image: 88
# no.of image: 89
# no.of image: 90
# no.of image: 91
# no.of image: 92
# no.of image: 93
# no.of image: 94
# no.of image: 95
# no.of image: 96
# no.of image: 97
# no.of image: 98
# no.of image: 99
# no.of image: 100
# no.of image: 101
# no.of image: 102
# no.of image: 103
# no.of image: 104
# no.of image: 105
# no.of image: 106
# no.of image: 107
# no.of image: 108
# no.of image: 109
# no.of image: 110
# no.of image: 111
# no.of image: 112
# no.of image: 113
# no.of image: 114
# no.of image: 115
# no.of image: 116
# no.of image: 117
# no.of image: 465
# no.of image: 466
# no.of image: 467
# no.of image: 468
# no.of image: 469
# no.of image: 470
# no.of image: 471
# no.of image: 472
# no.of image: 473
# no.of image: 474
# no.of image: 475
# no.of image: 476
# no.of image: 477
# no.of image: 478
# no.of image: 479
# no.of image: 480
# no.of image: 481
# no.of image: 482
# no.of image: 483
# no.of image: 484
# no.of image: 485
# no.of image: 486
# no.of image: 487
# no.of image: 488
# no.of image: 489
# no.of image: 490
# no.of image: 491
# no.of image: 492
# no.of image: 493
# no.of image: 494
# no.of image: 495
# no.of image: 496
# no.of image: 497
# no.of image: 498
# no.of image: 499
# no.of image: 500
# finished images download
# Downloading images for class: wine glass
# loading annotations into memory...
# Done (t=17.43s)
# creating index...
# index created!
# no.of image: 1
# no.of image: 2
# no.of image: 3
# no.of image: 4
# no.of image: 5
# no.of image: 6
# no.of image: 7
# no.of image: 8
# no.of image: 9
# no.of image: 10
# no.of image: 11
# no.of image: 12
# no.of image: 13
# no.of image: 14
# no.of image: 15
# no.of image: 16
# no.of image: 17
# no.of image: 18
# no.of image: 19
# no.of image: 20
# no.of image: 21
# no.of image: 22
# no.of image: 23
# no.of image: 24
# no.of image: 25
# no.of image: 26
# no.of image: 27
# no.of image: 28
# no.of image: 29
# no.of image: 30
# no.of image: 31
# no.of image: 32
# no.of image: 33
# no.of image: 34
# no.of image: 35
# no.of image: 36
# no.of image: 37
# no.of image: 38
# no.of image: 39
# no.of image: 40
# no.of image: 41
# no.of image: 42
# no.of image: 43
# no.of image: 44
# no.of image: 45
# no.of image: 46
# no.of image: 47
# no.of image: 48
# no.of image: 49
# no.of image: 50
# no.of image: 51
# no.of image: 52
# no.of image: 53
# no.of image: 54
# no.of image: 55
# no.of image: 56
# no.of image: 57
# no.of image: 58
# no.of image: 59
# no.of image: 60
# no.of image: 61
# no.of image: 62
# no.of image: 63
# no.of image: 64
# no.of image: 65
# no.of image: 66
# no.of image: 67
# no.of image: 68
# no.of image: 69
# no.of image: 70
# no.of image: 71
# no.of image: 72
# no.of image: 73
# no.of image: 74
# no.of image: 75
# no.of image: 76
# no.of image: 77
# no.of image: 78
# no.of image: 79
# no.of image: 80
# no.of image: 81
# no.of image: 82
# no.of image: 83
# no.of image: 84
# no.of image: 85
# no.of image: 86
# no.of image: 87
# no.of image: 88
# no.of image: 89
# no.of image: 90
# no.of image: 91
# no.of image: 92
# no.of image: 93
# no.of image: 94
# no.of image: 95
# no.of image: 96
# no.of image: 97
# no.of image: 98
# no.of image: 99
# no.of image: 100
# no.of image: 101
# no.of image: 102
# no.of image: 103
# no.of image: 104
# no.of image: 105
# no.of image: 106
# no.of image: 107
# no.of image: 108
# no.of image: 109
# no.of image: 110
# no.of image: 111
# no.of image: 112
# no.of image: 113
# no.of image: 114
# no.of image: 115
# no.of image: 116
# no.of image: 117
# no.of image: 118
# no.of image: 119
# no.of image: 120
# no.of image: 121
# no.of image: 122
# no.of image: 123
# no.of image: 124
# no.of image: 125
# no.of image: 126
# no.of image: 127
# no.of image: 128
# no.of image: 129
# no.of image: 130
# no.of image: 131
# no.of image: 132
# no.of image: 480
# no.of image: 481
# no.of image: 482
# no.of image: 483
# no.of image: 484
# no.of image: 485
# no.of image: 486
# no.of image: 487
# no.of image: 488
# no.of image: 489
# no.of image: 490
# no.of image: 491
# no.of image: 492
# no.of image: 493
# no.of image: 494
# no.of image: 495
# no.of image: 496
# no.of image: 497
# no.of image: 498
# no.of image: 499
# no.of image: 500
# finished images download
# Downloading images for class: cup
# loading annotations into memory...
# Done (t=17.51s)
# creating index...
# index created!
# no.of image: 1
# no.of image: 2
# no.of image: 3
# no.of image: 4
# no.of image: 5
# no.of image: 6
# no.of image: 7
# no.of image: 8
# no.of image: 9
# no.of image: 10
# no.of image: 11
# no.of image: 12
# no.of image: 13
# no.of image: 14
# no.of image: 15
# no.of image: 16
# no.of image: 17
# no.of image: 18
# no.of image: 19
# no.of image: 20
# no.of image: 21
# no.of image: 22
# no.of image: 23
# no.of image: 24
# no.of image: 25
# no.of image: 26
# no.of image: 27
# no.of image: 28
# no.of image: 29
# no.of image: 30
# no.of image: 31
# no.of image: 32
# no.of image: 33
# no.of image: 34
# no.of image: 35
# no.of image: 36
# no.of image: 37
# no.of image: 38
# no.of image: 39
# no.of image: 40
# no.of image: 41
# no.of image: 42
# no.of image: 43
# no.of image: 44
# no.of image: 45
# no.of image: 46
# no.of image: 47
# no.of image: 48
# no.of image: 49
# no.of image: 50
# no.of image: 51
# no.of image: 52
# no.of image: 53
# no.of image: 54
# no.of image: 55
# no.of image: 56
# no.of image: 57
# no.of image: 58
# no.of image: 59
# no.of image: 60
# no.of image: 61
# no.of image: 62
# no.of image: 63
# no.of image: 64
# no.of image: 65
# no.of image: 66
# no.of image: 67
# no.of image: 68
# no.of image: 69
# no.of image: 70
# no.of image: 71
# no.of image: 72
# no.of image: 73
# no.of image: 74
# no.of image: 75
# no.of image: 76
# no.of image: 77
# no.of image: 78
# no.of image: 79
# no.of image: 80
# no.of image: 81
# no.of image: 82
# no.of image: 83
# no.of image: 84
# no.of image: 85
# no.of image: 86
# no.of image: 87
# no.of image: 88
# no.of image: 89
# no.of image: 90
# no.of image: 91
# no.of image: 92
# no.of image: 93
# no.of image: 94
# no.of image: 95
# no.of image: 96
# no.of image: 97
# no.of image: 98
# no.of image: 99
# no.of image: 100
# no.of image: 101
# no.of image: 102
# no.of image: 103
# no.of image: 104
# no.of image: 105
# no.of image: 106
# no.of image: 107
# no.of image: 108
# no.of image: 109
# no.of image: 110
# no.of image: 111
# no.of image: 112
# no.of image: 113
# no.of image: 114
# no.of image: 115
# no.of image: 116
# no.of image: 117
# no.of image: 118
# no.of image: 119
# no.of image: 120
# no.of image: 121
# no.of image: 122
# no.of image: 123
# no.of image: 124
# no.of image: 125
# no.of image: 126
# no.of image: 127
# no.of image: 128
# no.of image: 129
# no.of image: 130
# no.of image: 131
# no.of image: 132
# no.of image: 133
# no.of image: 134
# no.of image: 135
# no.of image: 136
# no.of image: 137
# no.of image: 138
# no.of image: 139
# no.of image: 140
# no.of image: 141
# no.of image: 142
# no.of image: 143
# no.of image: 144
# no.of image: 145
# no.of image: 146
# no.of image: 147
# no.of image: 148
# no.of image: 149
# no.of image: 150
# no.of image: 151
# no.of image: 152
# no.of image: 153
# no.of image: 154
# no.of image: 155
# no.of image: 156
# no.of image: 157
# no.of image: 158
# no.of image: 159
# no.of image: 160
# no.of image: 161
# no.of image: 162
# no.of image: 163
# no.of image: 164
# no.of image: 165
# no.of image: 166
# no.of image: 167
# no.of image: 168
# no.of image: 169
# no.of image: 170
# no.of image: 171
# no.of image: 172
# no.of image: 173
# no.of image: 174
# no.of image: 175
# no.of image: 176
# no.of image: 177
# no.of image: 178
# no.of image: 179
# no.of image: 180
# no.of image: 181
# no.of image: 182
# no.of image: 183
# no.of image: 184
# no.of image: 185
# no.of image: 186
# no.of image: 187
# no.of image: 188
# no.of image: 189
# no.of image: 190
# no.of image: 191
# no.of image: 192
# no.of image: 193
# no.of image: 194
# no.of image: 195
# no.of image: 196
# no.of image: 197
# no.of image: 198
# no.of image: 199
# no.of image: 200
# no.of image: 201
# no.of image: 202
# no.of image: 203
# no.of image: 204
# no.of image: 205
# no.of image: 206
# no.of image: 207
# no.of image: 208
# no.of image: 209
# no.of image: 210
# no.of image: 211
# no.of image: 212
# no.of image: 213
# no.of image: 214
# no.of image: 215
# no.of image: 216
# no.of image: 217
# no.of image: 218
# no.of image: 219
# no.of image: 220
# no.of image: 221
# no.of image: 222
# no.of image: 223
# no.of image: 224
# no.of image: 225
# no.of image: 226
# no.of image: 227
# no.of image: 228
# no.of image: 229
# no.of image: 230
# no.of image: 231
# no.of image: 232
# no.of image: 233
# no.of image: 234
# no.of image: 235
# no.of image: 236
# no.of image: 237
# no.of image: 238
# no.of image: 239
# no.of image: 240
# no.of image: 241
# no.of image: 242
# no.of image: 243
# no.of image: 244
# no.of image: 245
# no.of image: 246
# no.of image: 247
# no.of image: 248
# no.of image: 249
# no.of image: 250
# no.of image: 251
# no.of image: 252
# no.of image: 253
# no.of image: 254
# no.of image: 255
# no.of image: 256
# no.of image: 257
# no.of image: 258
# no.of image: 259
# no.of image: 260
# no.of image: 261
# no.of image: 262
# no.of image: 263
# no.of image: 264
# no.of image: 265
# no.of image: 266
# no.of image: 267
# no.of image: 268
# no.of image: 269
# no.of image: 270
# no.of image: 271
# no.of image: 272
# no.of image: 273
# no.of image: 274
# no.of image: 275
# no.of image: 276
# no.of image: 277
# no.of image: 278
# no.of image: 279
# no.of image: 280
# no.of image: 281
# no.of image: 282
# no.of image: 283
# no.of image: 284
# no.of image: 285
# no.of image: 286
# no.of image: 287
# no.of image: 288
# no.of image: 289
# no.of image: 290
# no.of image: 291
# no.of image: 292
# no.of image: 293
# no.of image: 294
# no.of image: 295
# no.of image: 296
# no.of image: 297
# no.of image: 298
# no.of image: 299
# no.of image: 300
# no.of image: 301
# no.of image: 302
# no.of image: 303
# no.of image: 304
# no.of image: 305
# no.of image: 306
# no.of image: 307
# no.of image: 308
# no.of image: 309
# no.of image: 310
# no.of image: 311
# no.of image: 312
# no.of image: 313
# no.of image: 314
# no.of image: 315
# no.of image: 316
# no.of image: 317
# no.of image: 318
# no.of image: 319
# no.of image: 320
# no.of image: 321
# no.of image: 322
# no.of image: 323
# no.of image: 324
# no.of image: 325
# no.of image: 326
# no.of image: 327
# no.of image: 328
# no.of image: 329
# no.of image: 330
# no.of image: 331
# no.of image: 332
# no.of image: 333
# no.of image: 334
# no.of image: 335
# no.of image: 336
# no.of image: 337
# no.of image: 338
# no.of image: 339
# no.of image: 340
# no.of image: 341
# no.of image: 342
# no.of image: 343
# no.of image: 344
# no.of image: 345
# no.of image: 346
# no.of image: 347
# no.of image: 348
# no.of image: 349
# no.of image: 350
# no.of image: 351
# no.of image: 352
# no.of image: 353
# no.of image: 354
# no.of image: 355
# no.of image: 356
# no.of image: 357
# no.of image: 358
# no.of image: 359
# no.of image: 360
# no.of image: 361
# no.of image: 362
# no.of image: 363
# no.of image: 364
# no.of image: 365
# no.of image: 366
# no.of image: 367
# no.of image: 368
# no.of image: 369
# no.of image: 370
# no.of image: 371
# no.of image: 372
# no.of image: 373
# no.of image: 374
# no.of image: 375
# no.of image: 376
# no.of image: 377
# no.of image: 378
# no.of image: 379
# no.of image: 380
# no.of image: 381
# no.of image: 382
# no.of image: 383
# no.of image: 384
# no.of image: 385
# no.of image: 386
# no.of image: 387
# no.of image: 388
# no.of image: 389
# no.of image: 390
# no.of image: 391
# no.of image: 392
# no.of image: 393
# no.of image: 394
# no.of image: 395
# no.of image: 396
# no.of image: 397
# no.of image: 398
# no.of image: 399
# no.of image: 400
# no.of image: 401
# no.of image: 402
# no.of image: 403
# no.of image: 404
# no.of image: 405
# no.of image: 406
# no.of image: 407
# no.of image: 408
# no.of image: 409
# no.of image: 410
# no.of image: 411
# no.of image: 412
# no.of image: 413
# no.of image: 414
# no.of image: 415
# no.of image: 416
# no.of image: 417
# no.of image: 418
# no.of image: 419
# no.of image: 420
# no.of image: 421
# no.of image: 422
# no.of image: 423
# no.of image: 424
# no.of image: 425
# no.of image: 426
# no.of image: 427
# no.of image: 428
# no.of image: 429
# no.of image: 430
# no.of image: 431
# no.of image: 432
# no.of image: 433
# no.of image: 434
# no.of image: 435
# no.of image: 436
# no.of image: 437
# no.of image: 438
# no.of image: 439
# no.of image: 440
# no.of image: 441
# no.of image: 442
# no.of image: 443
# no.of image: 444
# no.of image: 445
# no.of image: 446
# no.of image: 447
# no.of image: 448
# no.of image: 449
# no.of image: 450
# no.of image: 451
# no.of image: 452
# no.of image: 453
# no.of image: 454
# no.of image: 455
# no.of image: 456
# no.of image: 457
# no.of image: 458
# no.of image: 459
# no.of image: 460
# no.of image: 461
# no.of image: 462
# no.of image: 463
# no.of image: 464
# no.of image: 465
# no.of image: 466
# no.of image: 467
# no.of image: 468
# no.of image: 469
# no.of image: 470
# no.of image: 471
# no.of image: 472
# no.of image: 473
# no.of image: 474
# no.of image: 475
# no.of image: 476
# no.of image: 477
# no.of image: 478
# no.of image: 479
# no.of image: 480
# no.of image: 481
# no.of image: 482
# no.of image: 483
# no.of image: 484
# no.of image: 485
# no.of image: 486
# no.of image: 487
# no.of image: 488
# no.of image: 489
# no.of image: 490
# no.of image: 491
# no.of image: 492
# no.of image: 493
# no.of image: 494
# no.of image: 495
# no.of image: 496
# no.of image: 497
# no.of image: 498
# no.of image: 499
# no.of image: 500
# finished images download

# %%
from torch.utils.data import Dataset
import os

class YOLODataset(Dataset):
    def __init__(self, img_dir, label_dir, transforms=None):
        self.img_dir = img_dir
        self.label_dir = label_dir
        self.transforms = transforms
        self.images = os.listdir(img_dir)
        
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir,self.images[idx])
        label_path = os.path.join(self.label_dir, self.images[idx].replace(".jpg", ".txt"))
        
        # Load Image
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Load Annotations
        boxes = []
        with open(label_path, "r") as f:
            for l in f.readlines():
                class_label, x, y, w, h = map(float, l.strip().split())
                boxes.append([class_label, x, y, w, h])
                
        if self.transforms:
            img = self.transforms(img)
        return img, torch.Tensor(boxes)

# %%
# Example: Initialize DataLoader
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
img_path = 'C:/Users/YOGA/Desktop/Master^ s3/NoSQL/repo/intelligent-recycling-system/data'
lbl_path = 'C:/Users/YOGA/Desktop/Master^ s3/NoSQL/repo/intelligent-recycling-system/label'
train_dataset = YOLODataset(img_dir=img_path, label_dir=lbl_path, transforms=ToTensor())
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 6
#       4 img_path = 'C:/Users/YOGA/Desktop/Master^ s3/NoSQL/repo/intelligent-recycling-system/data'
#       5 lbl_path = 'C:/Users/YOGA/Desktop/Master^ s3/NoSQL/repo/intelligent-recycling-system/label'
# ----> 6 train_dataset = YOLODataset(img_dir=img_path, label_dir=lbl_path, transforms=ToTensor())
#       7 train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
#
# Cell In[22], line 9, in YOLODataset.__init__(self, img_dir, label_dir, transforms)
#       7 self.label_dir = label_dir
#       8 self.transforms = transforms
# ----> 9 self.images = os.listdir(img_dir)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:/Users/YOGA/Desktop/Master^ s3/NoSQL/repo/intelligent-recycling-system/data'

# %%
train_dataset[1]
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 train_dataset[1]
#
# Cell In[22], line 20, in YOLODataset.__getitem__(self, idx)
#      18 # Load Image
#      19 img = cv2.imread(img_path)
# ---> 20 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      22 # Load Annotations
#      23 boxes = []
#
# error: OpenCV(4.10.0) C:\b\abs_e4cxka7_7g\croot\opencv-suite_1738943368733\work\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %% [markdown]
# ## Training

# %%
import torch.optim as optim

# init model, optimizer and loss function
model = YOLO(grid_size=7, num_classes=6, num_anchors=3)
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = yolo_loss

# Training loop
num_epochs = 20
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    
    for imgs, trgts in train_loader:
        
        #forward pass
        preds = model(imgs)
        
        #loss calcs
        loss = criterion(preds,trgts, num_classes=6)
        
        #Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()

        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[24], line 14
#      11 model.train()
#      12 epoch_loss = 0
# ---> 14 for imgs, trgts in train_loader:
#      15
#      16     #forward pass
#      17     preds = model(imgs)
#      19     #loss calcs
#
# File c:\Users\YOGA\.conda\envs\SRS_env\Lib\site-packages\torch\utils\data\dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\YOGA\.conda\envs\SRS_env\Lib\site-packages\torch\utils\data\dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\YOGA\.conda\envs\SRS_env\Lib\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[22], line 20, in YOLODataset.__getitem__(self, idx)
#      18 # Load Image
#      19 img = cv2.imread(img_path)
# ---> 20 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      22 # Load Annotations
#      23 boxes = []
#
# error: OpenCV(4.10.0) C:\b\abs_e4cxka7_7g\croot\opencv-suite_1738943368733\work\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %% [markdown]
# # Video capture

# %%
# To quit press (q)
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

while True:
    ret, img= cap.read()
    cv2.imshow('Webcam', img)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # What objects we will detect:
# Glasses
# Paper
# Plastic
